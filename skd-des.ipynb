# %%
from Crypto.Cipher import DES
from Crypto.Util.Padding import pad

def procces_key(key) :
    return key[:8]

text = "Kampus PSDku Madiun"
key = procces_key(b'1n1kunC1')

BLOCK_SIZE = 8

des = DES.new(key, DES.MODE_ECB)
padded_text = pad(text.encode(), BLOCK_SIZE)
encrypted_text = des.encrypt(padded_text)
decrypted_text = des.decrypt(encrypted_text)

print("Plain Teks : ", text)
print("Hasil Enkripsi : ", encrypted_text)
print("Hasil Dekripsi : ", decrypted_text.decode())
# Out:
# Plain Teks :  Kampus PSDku Madiun
# Hasil Enkripsi :  b'.\xa5\xa1\xf4\xa8\x15\xdfc\xc7\x88-K\x06\xd9|&\xc9\xe6A\xbf\xd2P\x0fy'
# Hasil Dekripsi :  Kampus PSDku Madiun
